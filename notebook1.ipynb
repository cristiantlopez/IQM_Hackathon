# %% [markdown]
# <h1>Total wind money available</h1>

# %%
import csv
import numpy as np

# %%
a= [1,2,3,4,5]
a.append(6)
a
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# read input data
data = np.loadtxt("input_data.csv", delimiter=",",skiprows=1)
# with open("input_data.csv", newline="", encoding="utf-8") as f:
#     reader = csv.reader(f, delimiter=",")
#     for row in reader:
#         times.append(row[0])
#         avg = np.mean(row[1:14])
#         avg_wind.append(avg)
#         price_per_wind.append(row[14])

times = data[:,0].astype(int)
wind = np.array(data[:,1:14])
price_per_wind = np.array(data[:,14])
# Out:
# array([ 88.96,  83.82,  83.  ,  82.56,  82.82,  86.01, 103.21, 133.09,
#        113.73,  70.89,  34.14,  19.97,  16.49,  13.72,  18.62,  33.65,
#         63.  , 110.37, 125.03, 147.6 , 151.42, 130.49, 102.28,  91.85])
